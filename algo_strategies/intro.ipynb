# %%
import pandas as pd
df = pd.read_csv('output.csv')
df
# Out:
#       Timestamp      Open      High       Low    Close  Volume  \
# 0    1706486400  21433.10  21763.20  21429.60  21737.6       0
# 1    1706572800  21775.80  21813.10  21501.80  21522.1       0
# 2    1706659200  21487.20  21741.30  21448.80  21725.7       0
# 3    1706745600  21780.70  21832.90  21658.80  21697.4       0
# 4    1706832000  21812.80  22126.80  21805.60  21853.8       0
# ..          ...       ...       ...       ...      ...     ...
# 226  1735171200  23775.80  23854.50  23653.60  23750.2       0
# 227  1735257600  23801.40  23938.85  23800.60  23813.4       0
# 228  1735516800  23796.90  23915.35  23599.30  23644.9       0
# 229  1735603200  23560.60  23689.85  23460.45  23644.8       0
# 230  1735689600  23637.65  23822.80  23562.80  23742.9       0
#
#                     Timestamp2
# 0    2024-01-29 05:30:00+05:30
# 1    2024-01-30 05:30:00+05:30
# 2    2024-01-31 05:30:00+05:30
# 3    2024-02-01 05:30:00+05:30
# 4    2024-02-02 05:30:00+05:30
# ...

# %%
import pandas_ta as ta
df['EMA'] = ta.ema(df.Close, length=10)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas_ta as ta
#       2 df['EMA'] = ta.ema(df.Close, length=10)
#       3 df
#
# File ~/development/fyers/venv/lib/python3.11/site-packages/pandas_ta/__init__.py:116
#      97 EXCHANGE_TZ = {
#      98     "NZSX": 12, "ASX": 11,
#      99     "TSE": 9, "HKE": 8, "SSE": 8, "SGX": 8,
#    (...)
#     102     "BMF": -2, "NYSE": -4, "TSX": -4
#     103 }
#     105 RATE = {
#     106     "DAYS_PER_MONTH": 21,
#     107     "MINUTES_PER_HOUR": 60,
#    (...)
#     113     "YEARLY": 1,
#     114 }
# --> 116 from pandas_ta.core import *
#
# File ~/development/fyers/venv/lib/python3.11/site-packages/pandas_ta/core.py:18
#      16 from pandas_ta.candles import *
#      17 from pandas_ta.cycles import *
# ---> 18 from pandas_ta.momentum import *
#      19 from pandas_ta.overlap import *
# ...
